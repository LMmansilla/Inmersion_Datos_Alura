# %%
import pandas as pd

# %%
inmuebles = pd.read_csv('E:\\JPY\\Inmersion_Datos_Alura\\data\inmuebles_bogota.csv') 
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# 3    $ 890.000.000
# 4    $ 970.000.000

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
columnas = {'Baños':'Banos','Área':'Area'}
inmuebles = inmuebles.rename(columns=columnas)
inmuebles.sample(10)
# Out:
#              Tipo                                  Descripcion  Habitaciones  \
# 8005  Apartamento  Apartamento en venta en Nicolas De Federman             3
# 1600  Apartamento         Apartamento en venta en San Patricio             2
# 8560  Apartamento       Apartamento en venta en Ciudad Bolívar             3
# 290   Apartamento          Apartamento en venta en El Contador             1
# 518   Apartamento              Apartamento en venta en Kennedy             1
# 511   Apartamento        Apartamento en venta en Santa Barbara             3
# 4580         Casa                   Casa en venta en Pasadena              3
# 8361  Apartamento             Apartamento en venta en Engativa             3
# 6075  Apartamento              Apartamento en venta en Kennedy             3
# 7277  Apartamento             Apartamento en venta en Engativa             3
#
#       Banos  Area               Barrio  \
# 8005      3   122  Nicolas De Federman
# 1600      2    63         San Patricio
# 8560      2    62       Ciudad Bolívar
# 290       2    58          El Contador
# 518       1    34              Kennedy
# 511       2    75        Santa Barbara
# 4580      3   161            Pasadena
# 8361      2    75             Engativa
# 6075      1    48              Kennedy
# 7277      2    62             Engativa
#
#                                                     UPZ          Valor
# 8005                                        Teusaquillo  $ 550.000.000
# 1600              USAQUÉN: Country Club + Santa Bárbara  $ 346.990.000
# 8560  CIUDAD BOLÍVAR: Monteblanco + El Tesoro + El M...  $ 200.000.000
# 290                                          Los Cedros  $ 380.000.000
# 518                                     Kennedy Central  $ 103.000.000
# 511               USAQUÉN: Country Club + Santa Bárbara  $ 314.000.000
# 4580                                                NaN  $ 950.000.000
# 8361                                           Engativá  $ 410.000.000
# 6075                                    Kennedy Central  $ 149.000.000
# 7277                                           Engativá  $ 242.000.000
